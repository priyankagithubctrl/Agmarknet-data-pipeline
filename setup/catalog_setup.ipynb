# %%
# %sql
CREATE CATALOG IF NOT EXISTS agmarknet;
USE CATALOG agmarknet;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS agmarknet.gold;
CREATE SCHEMA IF NOT EXISTS agmarknet.silver;
CREATE SCHEMA IF NOT EXISTS agmarknet.bronze;
